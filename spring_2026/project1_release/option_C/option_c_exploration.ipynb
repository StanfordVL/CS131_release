# %% [markdown]
# # Option C Exploration
#
# This notebook contains the exploration component for Option C, due the week after the main notebook.

# %% [markdown]
# ## Review of Current Methods
#
# Select at least 5 relevant resources and briefly describe each one.

# %% [markdown]
# ## Mini-Project
#
# Extend the ideas from the main notebook with your own implementation or experiment.

# %%
# Add your exploration code here

# %% [markdown]
# ## Writeup
#
# Explain what you did and how it relates to the main notebook topics.
